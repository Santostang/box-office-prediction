# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True, font_scale = 1.5)
import pandas as pd

# %%
df = pd.read_csv("box2016_mtc_trend_tie_miss.csv")
df0 = pd.read_csv("box2016.csv")
df_1 = df[['open_gross', 'open_thea', 'budget', 'runtime', 'Director_gross', 'Actor_gross', 'studio_gross', 'mean_score_mtc', 'comment_count_mtc', 'trend_a_week', 'trend_two_week', 'trend_a_day']]

# %%
#cols = ['open_gross', 'open_thea', 'budget', 'runtime', 'Director_gross', 'Actor_gross', 'studio_gross', 'mean_score_mtc', 'comment_count_mtc', 'trend_a_week', 'trend_two_week', 'trend_a_day']
#sns.pairplot(df.dropna(how='any')[cols],diag_kind='kde', size = 2.5)
#sns.pairplot(df_1,diag_kind='kde', size = 2.5)
sns.pairplot(df_1, diag_kind="kde", markers="+", plot_kws=dict(s=50, edgecolor="b", linewidth=1), diag_kws=dict(shade=True))
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
corrmat = df_1.dropna(axis=0, how='any').corr()
#cm = np.corrcoef(df_1.dropna(axis=0, how='any').values.T)
#k=12
#cols = corrmat.nlargest(k, 'total_gross')['total_gross'].index
ax = sns.heatmap(corrmat, annot=True, fmt='.2f', annot_kws={'size': 10}, center=1)
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
#ax = sns.boxplot(x="open_gross", y="genre", data=df0, palette=sns.light_palette((210, 90, 60), input="husl"))
#ax = sns.boxplot(x="open_gross", y="genre", data=df0, palette="GnBu_d")
ax = sns.boxplot(x="open_gross", y="genre", data=df0, palette="icefire")
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
plt.show()
